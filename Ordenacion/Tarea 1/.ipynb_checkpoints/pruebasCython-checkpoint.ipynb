# %%
# %%capture
# %run ordenaciones.ipynb
# %run funcionesPruebas.ipynb

# %%
px = [100, 200, 300, 400, 500]

resultadosBubble = correPruebas(bubbleSort, px)
resultadosBubbleC = correPruebas(bubbleSortC, px)

# %%
checaResultados(resultadosBubble)
# Out:
# True

# %%
checaResultados(resultadosBubbleC)
# Out:
# True

# %%
plotResults(resultadosBubble, 'o')
plotResults(resultadosBubbleC, '^')

# %%
px = [10000, 20000, 30000, 40000, 50000]

resultadosMerge = correPruebas(mergeSort, px)
resultadosMergeC = correPruebas(mergeSortC, px)

# %%
checaResultados(resultadosMerge)
# Out:
# True

# %%
checaResultados(resultadosMergeC)
# Out:
# True

# %%
plotResults(resultadosMerge, 'o')
plotResults(resultadosMergeC, '^')
