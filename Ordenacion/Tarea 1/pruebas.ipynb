# %%
# %%capture
# %run ordenaciones.ipynb
# %run funcionesPruebas.ipynb

# %%
px = [100, 200, 300, 400, 500]

# %%
resultadosBubble = correPruebas(bubbleSort, px)
resultadosInsertion = correPruebas(insertionSort, px)
resultadosMerge = correPruebas(mergeSort, px)

# %%
checaResultados(resultadosBubble)
# Out:
# True

# %%
plotResults(resultadosBubble, '*')

# %%
checaResultados(resultadosInsertion)
# Out:
# True

# %%
plotResults(resultadosInsertion, '^')

# %%
checaResultados(resultadosMerge)
# Out:
# True

# %%
plotResults(resultadosMerge, 's')

# %%
plotResults(resultadosInsertion, '^')
plotResults(resultadosMerge, 's')
plotResults(resultadosBubble, 'o')

# %%
px = [1000000]
resultadosMerge = correPruebas(mergeSort, px)

# %%
checaResultados(resultadosMerge)
# Out:
# True

# %%
plotResults(resultadosMerge, 's')

# %%
resultadosMerge['resultados']
# Out:
# [71.65150032657635]
